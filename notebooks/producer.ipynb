# %%
# !pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.10/site-packages (2.8.0)

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /opt/conda/lib/python3.10/site-packages (18.9.0)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.10/site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.4->faker) (1.16.0)

# %%
# !pip install protobuf
# Out:
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (5.29.3)

# %%
# !pip install --upgrade protobuf
# Out:
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (4.21.12)
# Collecting protobuf
#   Using cached protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
# Successfully installed protobuf-5.29.3

# %%
# !pip install googleapis-common-protos
# Out:
# Collecting googleapis-common-protos
#   Using cached googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from googleapis-common-protos) (5.29.3)
# Installing collected packages: googleapis-common-protos
# Successfully installed googleapis-common-protos-1.66.0

# %%
pip install --upgrade confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.10/site-packages (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from confluent_kafka import SerializingProducer
from confluent_kafka.serialization import StringSerializer
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.protobuf import ProtobufSerializer
from faker import Faker
import random
import os
import sys
import time

# %%
# Load environment variables from .env file
from dotenv import load_dotenv
dotenv_path = Path('/resources/.env')
# print(dotenv_path)
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
# Access environment variables
kafka_host = os.getenv('KAFKA_HOST_1')
topic_name = os.getenv('KAFKA_TOPIC_NAME')
replication_factor = int(os.getenv('KAFKA_REPLICATION'))
num_partitions = int(os.getenv('KAFKA_PARTITION'))
schema_registry_host = os.getenv('SCHEMA_REG_HOST')

# %%
# Protobuf schema import
sys.path.append('./protobuf')
import protobuf_schema_pb2

# %%
# # Kafka Configuration
bootstrap_servers = f'{kafka_host}:9092'
schema_registry_url = f'http://{schema_registry_host}:8081'

# %%
# Kafka Configuration
# bootstrap_servers = '172.22.0.3:9092'
# schema_registry_url = 'http://172.22.0.5:8081'

# %%
# Producer Configuration
producer_conf = {
    'bootstrap.servers': bootstrap_servers,
    'key.serializer': StringSerializer('utf_8'),
}

# %%
# Schema Registry and Protobuf Serializer
schema_registry_client = SchemaRegistryClient({'url': schema_registry_url})

protobuf_serializer = ProtobufSerializer(protobuf_schema_pb2.ProductSale,
                                         schema_registry_client,
                                         {'use.deprecated.format': False})

producer_conf['value.serializer'] = protobuf_serializer

# %%
# Kafka Producer
producer = SerializingProducer(producer_conf)
fake = Faker()

# %%
# Data generator function
def generate_product_sale_data():
    sale_data = protobuf_schema_pb2.ProductSale()
    sale_data.transaction_id = fake.uuid4()
    sale_data.sale_date = fake.date_time_this_year().strftime('%Y-%m-%d %H:%M:%S')
    sale_data.product = fake.random_element(elements=[
        'Hydrating Serum', 'Matte Lipstick', 'Vitamin C Serum',
        'Moisturizer', 'Eyeliner', 'Sunscreen', 'Foundation'
    ])
    sale_data.category = fake.random_element(elements=['Skincare', 'Makeup'])
    sale_data.unit_price = round(random.uniform(50000.0, 1000000.0), 2)  # Harga per unit (50-500)
    sale_data.units_sold = random.randint(1, 20)  # Unit terjual (1-20)
    sale_data.total_sales = round(sale_data.unit_price * sale_data.units_sold, 2)  # Total penjualan
    return sale_data

# Produce 300 messages    
for i in range(300):
    sale_data = generate_product_sale_data()
    try:
        print(f"Producing: {sale_data}")
        producer.produce(topic=topic_name, key=sale_data.transaction_id, value=sale_data)
        producer.flush()
        print(f"Message {i+1} sent")
    except Exception as e:
        print(f"Error sending message: {e}")
    time.sleep(5)  # Interval pengiriman data
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='dataeng-schema-registry' port=8081 local_address=None timeout=None socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7fc31ef0bdf0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 24 Jan 2025 16:03:59 GMT'), (b'X-Request-ID', b'a5d0395a-f0f4-4ae0-b0f8-b9ada7c51b8e'), (b'Content-Type', b'application/vnd.schemaregistry.v1+json'), (b'Vary', b'Accept-Encoding, User-Agent'), (b'Content-Length', b'8')])
# INFO:httpx:HTTP Request: POST http://dataeng-schema-registry:8081/subjects/test-topic-value/versions?normalize=False "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# Producing: transaction_id: "516b51d5-41aa-45eb-b520-e86512db4be9"
# sale_date: "2025-01-07 16:15:13"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 482510.48
# units_sold: 3
# total_sales: 1447531.44
#
# Message 1 sent
# Producing: transaction_id: "a11ce868-81a5-4f70-8ee6-851d195dfe6a"
# sale_date: "2025-01-08 17:56:08"
# product: "Hydrating Serum"
# category: "Skincare"
# unit_price: 212535.02
# units_sold: 1
# total_sales: 212535.02
#
# Message 2 sent
# Producing: transaction_id: "f732f970-6b30-4dd9-bded-4771fd230145"
# sale_date: "2025-01-18 19:21:46"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 547016.54
# units_sold: 19
# total_sales: 10393314.26
#
# Message 3 sent
# Producing: transaction_id: "eaf9b8c8-f27d-4515-8825-065acdf3a8cc"
# sale_date: "2025-01-16 02:45:08"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 527243.35
# units_sold: 4
# total_sales: 2108973.4
#
# Message 4 sent
# Producing: transaction_id: "d7db5d1d-cb63-4730-99b3-437047bc2d37"
# sale_date: "2025-01-23 09:49:30"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 129094.14
# units_sold: 15
# total_sales: 1936412.1
#
# Message 5 sent
# Producing: transaction_id: "0cced901-a4fd-43ad-9ee6-845f9689617a"
# sale_date: "2025-01-19 07:39:45"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 458229.85
# units_sold: 10
# total_sales: 4582298.5
#
# Message 6 sent
# Producing: transaction_id: "b65f7253-2280-4ff2-9abe-4c4dbf482436"
# sale_date: "2025-01-18 08:04:51"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 956492.55
# units_sold: 5
# total_sales: 4782462.75
#
# Message 7 sent
# Producing: transaction_id: "33be2070-39c8-470a-b7fd-6d191e7951e0"
# sale_date: "2025-01-17 01:19:52"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 373942.76
# units_sold: 19
# total_sales: 7104912.44
#
# Message 8 sent
# Producing: transaction_id: "6af7d6b3-11ef-4345-a125-761a80599705"
# sale_date: "2025-01-05 22:29:59"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 514592.23
# units_sold: 7
# total_sales: 3602145.61
#
# Message 9 sent
# Producing: transaction_id: "41236b78-eddb-4f39-841c-5cbf5293d969"
# sale_date: "2025-01-21 20:21:11"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 570126.96
# units_sold: 20
# total_sales: 11402539.2
#
# Message 10 sent
# Producing: transaction_id: "ad668550-9daf-4ae2-b905-321bcf293fbc"
# sale_date: "2025-01-08 19:04:42"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 685023.53
# units_sold: 18
# total_sales: 12330423.54
#
# Message 11 sent
# Producing: transaction_id: "b7544905-d86e-40f0-b896-25c83e5be15e"
# sale_date: "2025-01-03 10:13:16"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 417038.35
# units_sold: 14
# total_sales: 5838536.9
#
# Message 12 sent
# Producing: transaction_id: "01594bba-90ab-449a-8621-f909c2656485"
# sale_date: "2025-01-11 16:16:05"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 315329.27
# units_sold: 13
# total_sales: 4099280.51
#
# Message 13 sent
# Producing: transaction_id: "00c5de01-c61b-4ee5-8c0f-06b72553db83"
# sale_date: "2025-01-03 13:13:40"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 851928.59
# units_sold: 2
# total_sales: 1703857.18
#
# Message 14 sent
# Producing: transaction_id: "c0a7f4f7-a3b2-4807-b076-04dd4db4f75f"
# sale_date: "2025-01-12 18:40:56"
# product: "Foundation"
# category: "Makeup"
# unit_price: 419765.77
# units_sold: 3
# total_sales: 1259297.31
#
# Message 15 sent
# Producing: transaction_id: "f6b506a9-49a9-4eb5-bb32-9b2dc3aeb7d0"
# sale_date: "2025-01-15 06:20:21"
# product: "Hydrating Serum"
# category: "Skincare"
# unit_price: 915112.49
# units_sold: 19
# total_sales: 17387137.31
#
# Message 16 sent
# Producing: transaction_id: "9d4b96c2-d39a-495e-8f79-80e6c6d90513"
# sale_date: "2025-01-03 07:22:52"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 277983.12
# units_sold: 1
# total_sales: 277983.12
#
# Message 17 sent
# Producing: transaction_id: "ecb09652-aedb-41e9-8926-ef1a6a35baa6"
# sale_date: "2025-01-19 05:08:57"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 389931.87
# units_sold: 10
# total_sales: 3899318.7
#
# Message 18 sent
# Producing: transaction_id: "d6416ef7-d7c3-40b8-a327-08509d6f7b57"
# sale_date: "2025-01-15 16:04:01"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 201568.1
# units_sold: 18
# total_sales: 3628225.8
#
# Message 19 sent
# Producing: transaction_id: "18ec0992-ca25-4b6d-b621-22d30dd5b192"
# sale_date: "2025-01-14 10:35:50"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 438609.07
# units_sold: 6
# total_sales: 2631654.42
#
# Message 20 sent
# Producing: transaction_id: "05ecd732-0a76-48fa-8c14-5f5c82ef5894"
# sale_date: "2025-01-09 11:21:49"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 835423.64
# units_sold: 15
# total_sales: 12531354.6
#
# Message 21 sent
# Producing: transaction_id: "b1f776b1-864e-4bd9-aaa2-9cbf199624aa"
# sale_date: "2025-01-10 19:51:44"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 199091.78
# units_sold: 12
# total_sales: 2389101.36
#
# Message 22 sent
# Producing: transaction_id: "407bd047-74b7-4826-b003-94f6834e37b9"
# sale_date: "2025-01-14 11:20:33"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 804811.14
# units_sold: 8
# total_sales: 6438489.12
#
# Message 23 sent
# Producing: transaction_id: "7b32d23b-2cb8-4b89-af3c-95b011c581b7"
# sale_date: "2025-01-02 05:30:12"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 231846.98
# units_sold: 18
# total_sales: 4173245.64
#
# Message 24 sent
# Producing: transaction_id: "5f18cb77-335d-4d47-ae7a-6b92fbe7168b"
# sale_date: "2025-01-04 23:23:00"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 753879
# units_sold: 17
# total_sales: 12815943
#
# Message 25 sent
# Producing: transaction_id: "15870423-0bf3-4570-b283-39a6e69752aa"
# sale_date: "2025-01-19 08:20:32"
# product: "Foundation"
# category: "Makeup"
# unit_price: 478113.32
# units_sold: 10
# total_sales: 4781133.2
#
# Message 26 sent
# Producing: transaction_id: "40c6c5f8-9112-48d3-abe0-5bc81a6dff77"
# sale_date: "2025-01-03 19:02:09"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 125242.1
# units_sold: 3
# total_sales: 375726.3
#
# Message 27 sent
# Producing: transaction_id: "baba8b95-6446-4783-a923-d2d3c206e8a3"
# sale_date: "2025-01-14 06:38:17"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 539421.86
# units_sold: 11
# total_sales: 5933640.46
#
# Message 28 sent
# Producing: transaction_id: "5279db4f-0d61-4efd-820f-1698a12aacba"
# sale_date: "2025-01-10 06:37:38"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 135518.91
# units_sold: 4
# total_sales: 542075.64
#
# Message 29 sent
# Producing: transaction_id: "b4c21083-2ef7-4924-960a-84592b1f416c"
# sale_date: "2025-01-10 20:25:27"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 455675.25
# units_sold: 17
# total_sales: 7746479.25
#
# Message 30 sent
# Producing: transaction_id: "f3a8b182-b481-418e-a797-db71aa887f7e"
# sale_date: "2025-01-19 06:41:47"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 523892.88
# units_sold: 7
# total_sales: 3667250.16
#
# Message 31 sent
# Producing: transaction_id: "2adc75c2-76f3-4570-92df-7156d1869832"
# sale_date: "2025-01-03 21:40:11"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 623203.84
# units_sold: 4
# total_sales: 2492815.36
#
# Message 32 sent
# Producing: transaction_id: "068d0353-692a-4930-a5c6-d5a1c9499ed0"
# sale_date: "2025-01-08 10:03:53"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 910070.77
# units_sold: 12
# total_sales: 10920849.24
#
# Message 33 sent
# Producing: transaction_id: "b371ecc3-ef7c-4caa-ae4a-e08a6f760869"
# sale_date: "2025-01-11 22:29:49"
# product: "Hydrating Serum"
# category: "Skincare"
# unit_price: 766422.44
# units_sold: 19
# total_sales: 14562026.36
#
# Message 34 sent
# Producing: transaction_id: "8b5cb83d-de4d-4f21-9384-e951fd89c29e"
# sale_date: "2025-01-01 05:04:18"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 409574.24
# units_sold: 5
# total_sales: 2047871.2
#
# Message 35 sent
# Producing: transaction_id: "b47fc728-5afd-4662-9e3a-0333efb5bb9d"
# sale_date: "2025-01-20 09:18:03"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 755660.94
# units_sold: 19
# total_sales: 14357557.86
#
# Message 36 sent
# Producing: transaction_id: "a3c43330-72e5-400f-910b-8238f418bc2f"
# sale_date: "2025-01-09 17:14:07"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 765872.37
# units_sold: 3
# total_sales: 2297617.11
#
# Message 37 sent
# Producing: transaction_id: "7272f728-c72a-4ea2-81fb-0e6ece5ade78"
# sale_date: "2025-01-03 17:51:39"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 126473.46
# units_sold: 16
# total_sales: 2023575.36
#
# Message 38 sent
# Producing: transaction_id: "0f8d9a4e-24c7-45d1-a197-2eaf75a3c507"
# sale_date: "2025-01-15 15:35:22"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 798108.81
# units_sold: 16
# total_sales: 12769740.96
#
# Message 39 sent
# Producing: transaction_id: "12f6caab-148e-4ab9-8268-5e1905ead3ee"
# sale_date: "2025-01-17 23:22:29"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 827640.9
# units_sold: 3
# total_sales: 2482922.7
#
# Message 40 sent
# Producing: transaction_id: "4c118b0e-fce0-49f4-922d-071cc50552e2"
# sale_date: "2025-01-23 04:11:11"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 987809.54
# units_sold: 11
# total_sales: 10865904.94
#
# Message 41 sent
# Producing: transaction_id: "eec1a45e-c312-4832-a709-f52b3a33e2b1"
# sale_date: "2025-01-06 22:38:13"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 426667.03
# units_sold: 17
# total_sales: 7253339.51
#
# Message 42 sent
# Producing: transaction_id: "07a3350d-a4d1-442d-92c4-df24b10d4fc6"
# sale_date: "2025-01-04 18:15:17"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 643224.92
# units_sold: 18
# total_sales: 11578048.56
#
# Message 43 sent
# Producing: transaction_id: "cb3e99fd-7f3f-437d-b85c-a299cbb8c1a7"
# sale_date: "2025-01-18 20:30:43"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 97924.5
# units_sold: 2
# total_sales: 195849
#
# Message 44 sent
# Producing: transaction_id: "0a5751c3-ed20-4cde-8ac7-a5b17885eb3a"
# sale_date: "2025-01-16 16:55:37"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 420863.56
# units_sold: 18
# total_sales: 7575544.08
#
# Message 45 sent
# Producing: transaction_id: "0b895232-eac7-4a72-9ec8-78eaa39c3197"
# sale_date: "2025-01-23 04:39:19"
# product: "Foundation"
# category: "Skincare"
# unit_price: 899475.4
# units_sold: 17
# total_sales: 15291081.8
#
# Message 46 sent
# Producing: transaction_id: "bf865dc0-684e-4646-9712-cb918b8c5cd9"
# sale_date: "2025-01-12 15:11:19"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 921976.13
# units_sold: 7
# total_sales: 6453832.91
#
# Message 47 sent
# Producing: transaction_id: "4175b560-22c3-4cad-bffa-de9c722f44a4"
# sale_date: "2025-01-04 12:28:20"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 529428.59
# units_sold: 2
# total_sales: 1058857.18
#
# Message 48 sent
# Producing: transaction_id: "747dbadf-b31d-46a4-bc26-609a291ded03"
# sale_date: "2025-01-23 09:26:22"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 229727.45
# units_sold: 14
# total_sales: 3216184.3
#
# Message 49 sent
# Producing: transaction_id: "08067497-7e65-4591-b27b-fe053222d86f"
# sale_date: "2025-01-22 14:22:05"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 62415.22
# units_sold: 15
# total_sales: 936228.3
#
# Message 50 sent
# Producing: transaction_id: "c2234ab1-88b5-41cc-b31c-5562173b8c17"
# sale_date: "2025-01-18 23:03:54"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 291242.3
# units_sold: 9
# total_sales: 2621180.7
#
# Message 51 sent
# Producing: transaction_id: "3d2a9db0-0cde-4c41-8a47-66e70a6eeb59"
# sale_date: "2025-01-20 20:59:23"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 342621.19
# units_sold: 1
# total_sales: 342621.19
#
# Message 52 sent
# Producing: transaction_id: "538b899f-a360-4967-93e9-1eb80598d101"
# sale_date: "2025-01-05 12:32:19"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 667582.93
# units_sold: 19
# total_sales: 12684075.67
#
# Message 53 sent
# Producing: transaction_id: "cc47b911-4f98-493c-b4b4-4bd1f3125ce2"
# sale_date: "2025-01-03 15:27:59"
# product: "Foundation"
# category: "Skincare"
# unit_price: 989115.21
# units_sold: 18
# total_sales: 17804073.78
#
# Message 54 sent
# Producing: transaction_id: "5f0a31ac-35f3-4fdd-a77b-2cfe9b094f22"
# sale_date: "2025-01-14 00:58:26"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 150799.19
# units_sold: 2
# total_sales: 301598.38
#
# Message 55 sent
# Producing: transaction_id: "a637569e-01bb-4df9-a4ad-81799f722f7e"
# sale_date: "2025-01-05 20:53:05"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 589800.62
# units_sold: 2
# total_sales: 1179601.24
#
# Message 56 sent
# Producing: transaction_id: "3d8a38f3-2cdf-4044-a484-86fcdf702ad4"
# sale_date: "2025-01-19 03:26:05"
# product: "Foundation"
# category: "Makeup"
# unit_price: 445105.09
# units_sold: 15
# total_sales: 6676576.35
#
# Message 57 sent
# Producing: transaction_id: "3203fc6c-1287-4074-af88-808a8b826d2c"
# sale_date: "2025-01-20 04:01:24"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 620334.44
# units_sold: 14
# total_sales: 8684682.16
#
# Message 58 sent
# Producing: transaction_id: "e69216c0-9ec7-47ee-bb7c-cfc0c78071da"
# sale_date: "2025-01-16 08:35:24"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 680922.43
# units_sold: 1
# total_sales: 680922.43
#
# Message 59 sent
# Producing: transaction_id: "23228d20-8973-410a-8b7e-16d475fcd829"
# sale_date: "2025-01-17 19:21:43"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 382924.4
# units_sold: 2
# total_sales: 765848.8
#
# Message 60 sent
# Producing: transaction_id: "2f41f8cc-94cb-427e-9c99-b745209df5f6"
# sale_date: "2025-01-08 00:30:55"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 417851.2
# units_sold: 1
# total_sales: 417851.2
#
# Message 61 sent
# Producing: transaction_id: "e1c73be5-dd78-4b4b-8a23-097f124891c8"
# sale_date: "2025-01-18 03:26:41"
# product: "Hydrating Serum"
# category: "Skincare"
# unit_price: 726061.47
# units_sold: 3
# total_sales: 2178184.41
#
# Message 62 sent
# Producing: transaction_id: "13128cad-53a3-4f1a-aaa1-c1455e737024"
# sale_date: "2025-01-08 12:24:31"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 838757.99
# units_sold: 12
# total_sales: 10065095.88
#
# Message 63 sent
# Producing: transaction_id: "bb4a1fd5-972c-4b40-b79f-c660812cfe94"
# sale_date: "2025-01-15 16:09:43"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 873742.75
# units_sold: 16
# total_sales: 13979884
#
# Message 64 sent
# Producing: transaction_id: "22827225-b4c2-4e9a-a1c3-7b6f33e7abef"
# sale_date: "2025-01-03 20:02:41"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 313999.51
# units_sold: 1
# total_sales: 313999.51
#
# Message 65 sent
# Producing: transaction_id: "466278ec-7f04-4bf6-b5ab-153d718f2a8d"
# sale_date: "2025-01-21 19:47:09"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 295828.92
# units_sold: 8
# total_sales: 2366631.36
#
# Message 66 sent
# Producing: transaction_id: "f31f1de8-48dd-4f17-bd97-f598b15053b7"
# sale_date: "2025-01-04 11:17:14"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 638280.89
# units_sold: 16
# total_sales: 10212494.24
#
# Message 67 sent
# Producing: transaction_id: "131b8be1-d938-4b3f-88b3-de0a1b8e1fde"
# sale_date: "2025-01-04 20:55:32"
# product: "Hydrating Serum"
# category: "Skincare"
# unit_price: 571528.61
# units_sold: 19
# total_sales: 10859043.59
#
# Message 68 sent
# Producing: transaction_id: "7c8dff59-91cc-429f-82ed-98d39c7fe719"
# sale_date: "2025-01-17 07:58:51"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 466964.19
# units_sold: 20
# total_sales: 9339283.8
#
# Message 69 sent
# Producing: transaction_id: "e468ece9-2c0e-4b57-a4ca-fc43efa4e019"
# sale_date: "2025-01-04 06:42:33"
# product: "Foundation"
# category: "Makeup"
# unit_price: 688139.28
# units_sold: 15
# total_sales: 10322089.2
#
# Message 70 sent
# Producing: transaction_id: "79f6933e-1fe6-4b6e-a345-56a72f5dbcdd"
# sale_date: "2025-01-15 17:06:03"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 768054.67
# units_sold: 14
# total_sales: 10752765.38
#
# Message 71 sent
# Producing: transaction_id: "34cb0093-38ae-4a10-8730-343bb7db5454"
# sale_date: "2025-01-24 01:05:07"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 183674.17
# units_sold: 4
# total_sales: 734696.68
#
# Message 72 sent
# Producing: transaction_id: "a9325699-1125-4994-9814-e1b387a7fcc1"
# sale_date: "2025-01-07 00:26:06"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 392801.91
# units_sold: 5
# total_sales: 1964009.55
#
# Message 73 sent
# Producing: transaction_id: "ec29a738-7849-4c21-84e2-ef25f077a895"
# sale_date: "2025-01-02 07:31:11"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 446480.84
# units_sold: 2
# total_sales: 892961.68
#
# Message 74 sent
# Producing: transaction_id: "84a90e52-7b6a-467d-965b-5e34f9f6cd46"
# sale_date: "2025-01-24 05:37:35"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 938591.66
# units_sold: 8
# total_sales: 7508733.28
#
# Message 75 sent
# Producing: transaction_id: "1ef50b63-7b35-419d-8976-e1d759d1554f"
# sale_date: "2025-01-12 09:29:44"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 502829.68
# units_sold: 4
# total_sales: 2011318.72
#
# Message 76 sent
# Producing: transaction_id: "88ec2f0f-1601-45f6-bad5-3d8b4736b08c"
# sale_date: "2025-01-24 15:30:21"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 557277.11
# units_sold: 10
# total_sales: 5572771.1
#
# Message 77 sent
# Producing: transaction_id: "33d7af7e-f517-424f-88a3-2498288e5347"
# sale_date: "2025-01-19 03:33:40"
# product: "Foundation"
# category: "Makeup"
# unit_price: 178198.81
# units_sold: 10
# total_sales: 1781988.1
#
# Message 78 sent
# Producing: transaction_id: "3f816f0a-286b-4e0a-85ba-c7904f2b737a"
# sale_date: "2025-01-24 13:37:53"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 470229.81
# units_sold: 10
# total_sales: 4702298.1
#
# Message 79 sent
# Producing: transaction_id: "f6d41484-e17f-4b66-990c-68f413285fe4"
# sale_date: "2025-01-21 19:01:31"
# product: "Foundation"
# category: "Makeup"
# unit_price: 143888.93
# units_sold: 1
# total_sales: 143888.93
#
# Message 80 sent
# Producing: transaction_id: "29ccf993-a6ae-4633-ad47-b71f1c5c1529"
# sale_date: "2025-01-18 23:48:59"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 766127.24
# units_sold: 19
# total_sales: 14556417.56
#
# Message 81 sent
# Producing: transaction_id: "97a29482-4662-4abb-91b2-b2307ebe917d"
# sale_date: "2025-01-01 01:13:55"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 586139.57
# units_sold: 6
# total_sales: 3516837.42
#
# Message 82 sent
# Producing: transaction_id: "8a8eded5-c3ff-4950-9bc9-dbc09eba3ac5"
# sale_date: "2025-01-21 17:52:10"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 545076.42
# units_sold: 4
# total_sales: 2180305.68
#
# Message 83 sent
# Producing: transaction_id: "7aa207e6-e14b-454d-bbb6-3f77fdc18c51"
# sale_date: "2025-01-06 00:19:02"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 490687.07
# units_sold: 18
# total_sales: 8832367.26
#
# Message 84 sent
# Producing: transaction_id: "0b74824e-3792-489d-91e5-aae2a9ff280d"
# sale_date: "2025-01-10 23:00:48"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 229824.22
# units_sold: 19
# total_sales: 4366660.18
#
# Message 85 sent
# Producing: transaction_id: "852c6c38-59bf-4ace-92cb-7da38221b7a4"
# sale_date: "2025-01-02 09:07:14"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 884598.36
# units_sold: 12
# total_sales: 10615180.32
#
# Message 86 sent
# Producing: transaction_id: "bae6a532-8c59-4976-bf8e-1b8edbee5b24"
# sale_date: "2025-01-03 01:27:20"
# product: "Foundation"
# category: "Makeup"
# unit_price: 899707.81
# units_sold: 10
# total_sales: 8997078.1
#
# Message 87 sent
# Producing: transaction_id: "62d1c6e1-a90d-4c06-9638-7ae8c5176be0"
# sale_date: "2025-01-21 23:50:33"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 577467.14
# units_sold: 14
# total_sales: 8084539.96
#
# Message 88 sent
# Producing: transaction_id: "52e8b38c-d84b-46e9-a4a7-f3ad90a2b195"
# sale_date: "2025-01-07 15:59:46"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 191482.5
# units_sold: 9
# total_sales: 1723342.5
#
# Message 89 sent
# Producing: transaction_id: "0cea998a-2997-4f16-9d8d-59ec6bc1ce37"
# sale_date: "2025-01-14 00:42:25"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 156446.05
# units_sold: 1
# total_sales: 156446.05
#
# Message 90 sent
# Producing: transaction_id: "96f9c061-a80a-4bde-9094-970f8f958d1a"
# sale_date: "2025-01-02 06:16:40"
# product: "Foundation"
# category: "Makeup"
# unit_price: 378856.58
# units_sold: 20
# total_sales: 7577131.6
#
# Message 91 sent
# Producing: transaction_id: "4e8a13d5-d898-4395-912c-965206389043"
# sale_date: "2025-01-14 19:20:16"
# product: "Foundation"
# category: "Makeup"
# unit_price: 514895.27
# units_sold: 6
# total_sales: 3089371.62
#
# Message 92 sent
# Producing: transaction_id: "8d721b4b-efe0-4304-95de-42146c132047"
# sale_date: "2025-01-12 00:14:01"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 416420.23
# units_sold: 11
# total_sales: 4580622.53
#
# Message 93 sent
# Producing: transaction_id: "d7349d16-7c53-4b7b-bf20-7e06cde45862"
# sale_date: "2025-01-20 20:48:39"
# product: "Foundation"
# category: "Makeup"
# unit_price: 847689.89
# units_sold: 2
# total_sales: 1695379.78
#
# Message 94 sent
# Producing: transaction_id: "f707a30c-0d01-486d-854a-8807c909e10b"
# sale_date: "2025-01-11 09:04:36"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 861923.95
# units_sold: 17
# total_sales: 14652707.15
#
# Message 95 sent
# Producing: transaction_id: "06f4c0a1-3498-4bd0-8757-1fc5fb4f65d4"
# sale_date: "2025-01-13 07:18:34"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 935339.54
# units_sold: 2
# total_sales: 1870679.08
#
# Message 96 sent
# Producing: transaction_id: "4dc28b54-5845-4831-9570-52340f37f3a1"
# sale_date: "2025-01-21 13:33:46"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 164344.59
# units_sold: 9
# total_sales: 1479101.31
#
# Message 97 sent
# Producing: transaction_id: "decf3bd4-651f-4569-822d-b0c05a51eac9"
# sale_date: "2025-01-21 14:38:26"
# product: "Vitamin C Serum"
# category: "Skincare"
# unit_price: 885422.35
# units_sold: 17
# total_sales: 15052179.95
#
# Message 98 sent
# Producing: transaction_id: "49775ef8-486c-4109-b074-c0ed0526d9ad"
# sale_date: "2025-01-13 12:26:34"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 694083.18
# units_sold: 4
# total_sales: 2776332.72
#
# Message 99 sent
# Producing: transaction_id: "39ff30da-013d-4282-ad54-040f5c9524f7"
# sale_date: "2025-01-15 23:01:55"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 270755.38
# units_sold: 4
# total_sales: 1083021.52
#
# Message 100 sent
# Producing: transaction_id: "763789c2-8417-44fc-adbe-242710da7cd2"
# sale_date: "2025-01-05 20:33:39"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 662002.65
# units_sold: 19
# total_sales: 12578050.35
#
# Message 101 sent
# Producing: transaction_id: "1a47f6c7-4365-4f75-95b2-4a517137839c"
# sale_date: "2025-01-20 21:15:37"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 749167.26
# units_sold: 20
# total_sales: 14983345.2
#
# Message 102 sent
# Producing: transaction_id: "706f4b6b-1ffb-4289-84bc-3f7e92393889"
# sale_date: "2025-01-23 18:19:28"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 960776.23
# units_sold: 11
# total_sales: 10568538.53
#
# Message 103 sent
# Producing: transaction_id: "7df463a6-2b26-4225-9744-86d002237356"
# sale_date: "2025-01-22 10:18:06"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 449217.01
# units_sold: 4
# total_sales: 1796868.04
#
# Message 104 sent
# Producing: transaction_id: "cbd01129-ecaa-487f-8a9e-f8d98490dc37"
# sale_date: "2025-01-06 01:54:55"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 51012.85
# units_sold: 15
# total_sales: 765192.75
#
# Message 105 sent
# Producing: transaction_id: "88178ccf-2585-45eb-9274-440aead327b7"
# sale_date: "2025-01-19 20:58:29"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 672818.94
# units_sold: 16
# total_sales: 10765103.04
#
# Message 106 sent
# Producing: transaction_id: "036c214f-21d8-4627-8a25-adc518d6caa8"
# sale_date: "2025-01-15 05:46:52"
# product: "Foundation"
# category: "Skincare"
# unit_price: 458780.48
# units_sold: 1
# total_sales: 458780.48
#
# Message 107 sent
# Producing: transaction_id: "3b40652b-a5e5-450e-951c-9db405f2dd30"
# sale_date: "2025-01-07 06:46:17"
# product: "Foundation"
# category: "Skincare"
# unit_price: 316250.22
# units_sold: 6
# total_sales: 1897501.32
#
# Message 108 sent
# Producing: transaction_id: "877017e6-20f4-4d81-9766-13eb3d3832ed"
# sale_date: "2025-01-03 20:54:59"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 102263.09
# units_sold: 5
# total_sales: 511315.45
#
# Message 109 sent
# Producing: transaction_id: "be182c6c-7197-4181-93ff-a7a090acad7c"
# sale_date: "2025-01-22 03:58:32"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 855025.47
# units_sold: 6
# total_sales: 5130152.82
#
# Message 110 sent
# Producing: transaction_id: "f5395e95-f67a-4575-ab37-74e1a76b0af9"
# sale_date: "2025-01-01 13:41:43"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 832941.58
# units_sold: 17
# total_sales: 14160006.86
#
# Message 111 sent
# Producing: transaction_id: "63251ad8-2dac-416b-97d3-f68459d958f9"
# sale_date: "2025-01-11 01:16:57"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 206293.94
# units_sold: 20
# total_sales: 4125878.8
#
# Message 112 sent
# Producing: transaction_id: "ba098799-1891-4fea-a64f-ad869c8bbdd2"
# sale_date: "2025-01-12 14:36:39"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 932544.02
# units_sold: 14
# total_sales: 13055616.28
#
# Message 113 sent
# Producing: transaction_id: "aa98beb6-68c1-4488-b5e2-6f3fd46a3a4e"
# sale_date: "2025-01-03 16:21:59"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 282025.08
# units_sold: 4
# total_sales: 1128100.32
#
# Message 114 sent
# Producing: transaction_id: "2ea413a2-00fe-4415-9057-bba1e4e9117a"
# sale_date: "2025-01-01 09:18:06"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 761654.15
# units_sold: 12
# total_sales: 9139849.8
#
# Message 115 sent
# Producing: transaction_id: "744ec812-e1df-4540-87ff-9e31509ebf2c"
# sale_date: "2025-01-14 13:51:32"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 686428.27
# units_sold: 15
# total_sales: 10296424.05
#
# Message 116 sent
# Producing: transaction_id: "02cc021a-7e9f-4c96-8ce0-34543f72260d"
# sale_date: "2025-01-24 12:10:57"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 614864.48
# units_sold: 20
# total_sales: 12297289.6
#
# Message 117 sent
# Producing: transaction_id: "ee25d3a7-b8aa-40b7-87c6-5e3f5e14ee15"
# sale_date: "2025-01-19 14:46:31"
# product: "Moisturizer"
# category: "Skincare"
# unit_price: 812377.12
# units_sold: 8
# total_sales: 6499016.96
#
# Message 118 sent
# Producing: transaction_id: "e1852061-215b-499f-adbe-903af55afd3e"
# sale_date: "2025-01-03 03:09:22"
# product: "Foundation"
# category: "Skincare"
# unit_price: 870562.66
# units_sold: 12
# total_sales: 10446751.92
#
# Message 119 sent
# Producing: transaction_id: "f3d18d43-6e67-4521-b10c-7ebe639e9015"
# sale_date: "2025-01-15 04:49:10"
# product: "Eyeliner"
# category: "Makeup"
# unit_price: 251761.72
# units_sold: 5
# total_sales: 1258808.6
#
# Message 120 sent
# Producing: transaction_id: "f7c14ce7-51f4-4064-9075-ca267a8efb07"
# sale_date: "2025-01-14 06:26:18"
# product: "Foundation"
# category: "Skincare"
# unit_price: 468703.68
# units_sold: 16
# total_sales: 7499258.88
#
# Message 121 sent
# Producing: transaction_id: "64f37200-cb7b-4fb3-a6f5-224aa0743a1b"
# sale_date: "2025-01-18 02:20:38"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 845665.96
# units_sold: 15
# total_sales: 12684989.4
#
# Message 122 sent
# Producing: transaction_id: "83dc0415-43e9-4d8e-af4f-f8c74331630f"
# sale_date: "2025-01-08 02:17:21"
# product: "Hydrating Serum"
# category: "Skincare"
# unit_price: 478194.12
# units_sold: 12
# total_sales: 5738329.44
#
# Message 123 sent
# Producing: transaction_id: "945314ab-e372-4ff5-bcb0-46b8d167aaa2"
# sale_date: "2025-01-19 15:35:45"
# product: "Eyeliner"
# category: "Skincare"
# unit_price: 619055.89
# units_sold: 1
# total_sales: 619055.89
#
# Message 124 sent
# Producing: transaction_id: "ceb11aff-cabb-4a09-912b-10bd7caea373"
# sale_date: "2025-01-22 15:09:30"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 706527.68
# units_sold: 11
# total_sales: 7771804.48
#
# Message 125 sent
# Producing: transaction_id: "33950d11-16ea-4ffc-ab90-a310960b03d1"
# sale_date: "2025-01-16 02:54:56"
# product: "Foundation"
# category: "Makeup"
# unit_price: 619462.53
# units_sold: 1
# total_sales: 619462.53
#
# Message 126 sent
# Producing: transaction_id: "248763e0-140b-44d9-aa7d-1cf90ae53570"
# sale_date: "2025-01-12 07:27:00"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 813239.35
# units_sold: 9
# total_sales: 7319154.15
#
# Message 127 sent
# Producing: transaction_id: "d5402d8d-63d0-43e9-9d3d-61c719751b7d"
# sale_date: "2025-01-16 11:53:55"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 918528.54
# units_sold: 14
# total_sales: 12859399.56
#
# Message 128 sent
# Producing: transaction_id: "0b4c5a35-41e6-4b6a-8c7c-50763a6e2869"
# sale_date: "2025-01-08 02:58:40"
# product: "Foundation"
# category: "Makeup"
# unit_price: 864561.24
# units_sold: 13
# total_sales: 11239296.12
#
# Message 129 sent
# Producing: transaction_id: "d5b00194-701b-404b-b42b-9428abbdaa78"
# sale_date: "2025-01-07 03:14:35"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 251072.92
# units_sold: 1
# total_sales: 251072.92
#
# Message 130 sent
# Producing: transaction_id: "d3c1c5e8-19ec-44b1-b6b9-efcdef7b2d52"
# sale_date: "2025-01-03 09:08:48"
# product: "Sunscreen"
# category: "Skincare"
# unit_price: 388427.64
# units_sold: 12
# total_sales: 4661131.68
#
# Message 131 sent
# Producing: transaction_id: "fc777e76-0a59-4168-aa13-721bfdd48b93"
# sale_date: "2025-01-07 20:24:38"
# product: "Foundation"
# category: "Skincare"
# unit_price: 134791.8
# units_sold: 6
# total_sales: 808750.8
#
# Message 132 sent
# Producing: transaction_id: "111ec573-1c99-4485-ade1-a034c10109fe"
# sale_date: "2025-01-14 09:26:38"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 556367.44
# units_sold: 15
# total_sales: 8345511.6
#
# Message 133 sent
# Producing: transaction_id: "de110e52-575c-4304-99ab-a42243ce7f55"
# sale_date: "2025-01-07 15:16:15"
# product: "Matte Lipstick"
# category: "Makeup"
# unit_price: 514014.42
# units_sold: 15
# total_sales: 7710216.3
#
# Message 134 sent
# Producing: transaction_id: "323605ed-b7f4-4cbb-bef2-53ec71cde6f3"
# sale_date: "2025-01-19 18:21:28"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 888446.88
# units_sold: 1
# total_sales: 888446.88
#
# Message 135 sent
# Producing: transaction_id: "d8074fdf-81ab-4f75-8f0f-31d001431da3"
# sale_date: "2025-01-12 09:18:25"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 194197
# units_sold: 8
# total_sales: 1553576
#
# Message 136 sent
# Producing: transaction_id: "cc158c91-2af3-4115-8dbd-b7078b1344ae"
# sale_date: "2025-01-23 21:48:46"
# product: "Vitamin C Serum"
# category: "Makeup"
# unit_price: 631736.19
# units_sold: 10
# total_sales: 6317361.9
#
# Message 137 sent
# Producing: transaction_id: "d26ad5af-9bb5-414d-9ddc-325970456890"
# sale_date: "2025-01-19 07:34:52"
# product: "Moisturizer"
# category: "Makeup"
# unit_price: 498564.45
# units_sold: 17
# total_sales: 8475595.65
#
# Message 138 sent
# Producing: transaction_id: "459aaf95-632b-4c81-bbe8-046784eba2bc"
# sale_date: "2025-01-06 03:06:30"
# product: "Matte Lipstick"
# category: "Skincare"
# unit_price: 551834.24
# units_sold: 14
# total_sales: 7725679.36
#
# Message 139 sent
# Producing: transaction_id: "a741175e-19ed-4981-9cf3-54a312401b2b"
# sale_date: "2025-01-14 07:39:42"
# product: "Sunscreen"
# category: "Makeup"
# unit_price: 617039.45
# units_sold: 6
# total_sales: 3702236.7
#
# Message 140 sent
# Producing: transaction_id: "4cfdeda4-8961-435f-8ed1-bf30c2d5c044"
# sale_date: "2025-01-02 14:03:06"
# product: "Hydrating Serum"
# category: "Makeup"
# unit_price: 169436.23
# units_sold: 19
# total_sales: 3219288.37
#
# Message 141 sent
